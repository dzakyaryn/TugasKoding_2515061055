# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 55
type(x)
# Out:
# int

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
y = 5
type(x)
# Out:
# int

# %%
#jumlahkan x dengan y
xy_sum = x+y
xy_sum
# Out:
# 43

# %%
#jumlahkan x_float dengan y
x_float = 3.14
float_sum = x_float+y
float_sum
# Out:
# 10.14

# %%
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(55)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=55>

# %%
y_tf = tf.Variable(5)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=5>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=60>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=60>

# %%
import torch

# %%
x_pt = torch.tensor(55)
x_pt
# Out:
# tensor(55)

# %%
y_pt = torch.tensor(5)
y_pt
# Out:
# tensor(5)

# %%
x_pt+y_pt
# Out:
# tensor(60)
